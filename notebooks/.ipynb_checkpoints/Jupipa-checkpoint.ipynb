# %% [markdown]
# # Jupipa - Modelo de otimização de rotas de carros-pipa utilizando Julia

# %% [markdown]
# ### Resolvendo o modelo de programação linear utilizando o JuMP
#
#
# Para resolver um problema de programação linear tradicional para o problema de otimização de distribuição:
#
# $$
# \begin{align}
# & \text{minimizar} && c^T x \\
# & \text{sujeito a} && A x \leq b \\
# &                   && x \succeq 0 \\
# &                   && x \in \mathbb{R}^n
# \end{align}
# $$
# onde $c^T \in \mathbb{R}^n$ é a transformação linear que desejamos minimizar, ou custo, $A$ é uma matrix $n \times n$ que define as restrições do problema.

# %% [markdown]
# A variável de decisão para este problema é
# $$
# \begin{align}
# \forall (p,o,d) \in R \quad \left(x_{(p,o,d)}= \text{quantia do produto } p \text{ que é transportado da origem } o \text{ para o destino d} \right)
# \end{align}
# $$

# %%
using JuMP, DelimitedFiles, GLPK

# %%
oferta = readdlm("oferta.txt");
demanda = readdlm("demanda.txt");
Distancias = readdlm("distancias.txt");
noferta = size(oferta,1)
ndemanda = size(demanda,1);

# %%
Distancias
# Out:
# 5×3 Array{Float64,2}:
#  1.0  10.0  2.0
#  1.0  10.0  2.0
#  1.0  10.0  2.0
#  1.0  10.0  2.0
#  1.0  10.0  2.0

# %%
Dist = Distancias[:,2:4]
for i in range(1,stop=size(Dist,1))
    for j in range(1,stop=size(Dist,2))
        D = replace(Dist[i,j],"."=>"")
        Dist[i,j] = parse(Float64,(replace(D,","=>".")))    
    end
end
Dist = [Distancias[:,1] Dist];

# %%
#MODEL CONSTRUCTION
LpModel = Model(with_optimizer(GLPK.Optimizer)) 
#VARIABLES
@variable(LpModel, x[1:ndemanda*noferta] >= 0) # Models x >=0
#OBJECTIVE
@objective(LpModel, Min,sum(Dist[i,j+1]*x[j+(i-1)*noferta] for i in 1:ndemanda for j in 1:noferta));

# %%
#CONSTRAINTS
#demanda e oferta
for i in 1:ndemanda
    @constraint(LpModel, sum(x[j+(i-1)*noferta] for j in 1:noferta) == demanda[i,2]) # the ith row 
end 
for j in 1:noferta
    @constraint(LpModel, sum(x[j+(i-1)*noferta] for i in 1:ndemanda) <= oferta[j,2]) # the ith row 
end

# %%
#SOLVE IT
# finally optimize the model
@time begin
status = JuMP.optimize!(LpModel) # solves the model
end
# TEST SOLVER STATUSES
@show JuMP.has_values(LpModel)
@show JuMP.termination_status(LpModel)
@show JuMP.primal_status(LpModel) == MOI.FEASIBLE_POINT;
# Out:
#  23.309322 seconds (24.77 M allocations: 1.214 GiB, 6.86% gc time)
# JuMP.has_values(LpModel) = true
# JuMP.termination_status(LpModel) = OPTIMAL::TerminationStatusCode = 1
# JuMP.primal_status(LpModel) == MOI.FEASIBLE_POINT = true

# %%
# DISPLAY THE RESULTS
#-------------------------------- 
println("Objective value: ", JuMP.objective_value(LpModel)) # JuMP.objectivevalue(model_name) gives the optimum objective value
#println("Optimal solution is x = \n", JuMP.value.(x)) # JuMP.resultvalue(decision_variable) will give the optimum value 

[println("destino: ",demanda[i],", origem: ",oferta[j],", carros: ",JuMP.value.(x)[j+(i-1)*noferta]) for i in 1:ndemanda for j in 1:noferta if JuMP.value.(x)[j+(i-1)*noferta] >0];
# Out:
# Objective value: 1.6271963549999995e7
# destino: 2655.0, origem: 2703.0, carros: 2.0
# destino: 18309.0, origem: 2715.0, carros: 3.0
# destino: 18310.0, origem: 2715.0, carros: 1.0
# destino: 18316.0, origem: 2715.0, carros: 1.0
# destino: 18318.0, origem: 2715.0, carros: 2.0
# destino: 18319.0, origem: 2703.0, carros: 2.0
# destino: 18322.0, origem: 2703.0, carros: 2.0
# destino: 18324.0, origem: 2715.0, carros: 3.0
# destino: 18332.0, origem: 100.0, carros: 4.0
# destino: 18338.0, origem: 2703.0, carros: 6.0
# destino: 18345.0, origem: 100.0, carros: 4.0
# destino: 18347.0, origem: 2715.0, carros: 3.0
# destino: 18349.0, origem: 2715.0, carros: 2.0
# destino: 18354.0, origem: 100.0, carros: 3.0
# destino: 18355.0, origem: 2715.0, carros: 1.0
# destino: 18359.0, origem: 100.0, carros: 1.0
# destino: 18363.0, origem: 100.0, carros: 1.0
# destino: 18365.0, origem: 2715.0, carros: 2.0
# destino: 18366.0, origem: 2715.0, carros: 1.0
# destino: 18367.0, origem: 2715.0, carros: 1.0
# destino: 18368.0, origem: 2715.0, carros: 2.0
# destino: 18372.0, origem: 2715.0, carros: 2.0
# destino: 18374.0, origem: 2715.0, carros: 1.0
# destino: 18376.0, origem: 2715.0, carros: 3.0
# destino: 18386.0, origem: 2715.0, carros: 7.0
# destino: 18388.0, origem: 100.0, carros: 4.0
# destino: 18390.0, origem: 100.0, carros: 2.0
# destino: 18393.0, origem: 100.0, carros: 6.0
# destino: 18409.0, origem: 100.0, carros: 2.0
# destino: 18411.0, origem: 2703.0, carros: 1.0
# destino: 18412.0, origem: 2715.0, carros: 2.0
# destino: 18416.0, origem: 100.0, carros: 5.0
# destino: 18420.0, origem: 100.0, carros: 4.0
# destino: 18421.0, origem: 100.0, carros: 2.0
# destino: 18424.0, origem: 100.0, carros: 5.0
# destino: 18425.0, origem: 100.0, carros: 1.0
# destino: 18432.0, origem: 2715.0, carros: 3.0
# destino: 18433.0, origem: 2715.0, carros: 1.0
# destino: 18435.0, origem: 2715.0, carros: 3.0
# destino: 18438.0, origem: 100.0, carros: 5.0
# destino: 18442.0, origem: 2703.0, carros: 2.0
# destino: 18444.0, origem: 100.0, carros: 4.0
# destino: 18453.0, origem: 2715.0, carros: 6.0
# destino: 24347.0, origem: 2703.0, carros: 4.0
# destino: 37319.0, origem: 100.0, carros: 1.0
# destino: 37331.0, origem: 100.0, carros: 1.0
# destino: 37340.0, origem: 2703.0, carros: 6.0
# destino: 46732.0, origem: 2703.0, carros: 1.0
# destino: 46997.0, origem: 2715.0, carros: 1.0
# destino: 47056.0, origem: 2703.0, carros: 5.0
# destino: 47083.0, origem: 100.0, carros: 4.0
# destino: 47084.0, origem: 100.0, carros: 2.0
# destino: 47087.0, origem: 2703.0, carros: 1.0
# destino: 47088.0, origem: 100.0, carros: 4.0
# destino: 47120.0, origem: 2715.0, carros: 1.0
# destino: 47233.0, origem: 2715.0, carros: 2.0
# destino: 57191.0, origem: 100.0, carros: 1.0
# destino: 57197.0, origem: 100.0, carros: 1.0
# destino: 72542.0, origem: 2715.0, carros: 2.0
# destino: 72544.0, origem: 100.0, carros: 1.0
# destino: 72942.0, origem: 2715.0, carros: 2.0
# destino: 72946.0, origem: 2703.0, carros: 3.0
# destino: 73159.0, origem: 2715.0, carros: 5.0
# destino: 73160.0, origem: 100.0, carros: 1.0
# destino: 73165.0, origem: 100.0, carros: 2.0
# destino: 88318.0, origem: 2703.0, carros: 5.0
# destino: 88322.0, origem: 100.0, carros: 1.0
# destino: 88328.0, origem: 100.0, carros: 5.0
# destino: 88357.0, origem: 100.0, carros: 1.0
# destino: 88370.0, origem: 100.0, carros: 3.0
# destino: 88389.0, origem: 100.0, carros: 3.0
# destino: 88566.0, origem: 2703.0, carros: 4.0
# destino: 88641.0, origem: 100.0, carros: 1.0
# destino: 88649.0, origem: 2703.0, carros: 1.0
# destino: 88655.0, origem: 100.0, carros: 9.0
# destino: 88656.0, origem: 100.0, carros: 12.0
# destino: 88657.0, origem: 100.0, carros: 2.0
# destino: 88659.0, origem: 2715.0, carros: 2.0
# destino: 88661.0, origem: 100.0, carros: 1.0
# destino: 88690.0, origem: 100.0, carros: 1.0
# destino: 88691.0, origem: 2715.0, carros: 5.0
# destino: 88699.0, origem: 100.0, carros: 1.0
# destino: 88705.0, origem: 2715.0, carros: 5.0
# destino: 88707.0, origem: 2715.0, carros: 1.0
# destino: 88724.0, origem: 100.0, carros: 2.0
# destino: 88740.0, origem: 100.0, carros: 3.0
# destino: 88747.0, origem: 100.0, carros: 2.0
# destino: 88756.0, origem: 100.0, carros: 4.0
# destino: 88758.0, origem: 100.0, carros: 5.0
# destino: 88761.0, origem: 100.0, carros: 3.0
# destino: 88763.0, origem: 100.0, carros: 2.0
# destino: 88767.0, origem: 100.0, carros: 2.0
# destino: 88769.0, origem: 2715.0, carros: 1.0
# destino: 88788.0, origem: 100.0, carros: 1.0
# destino: 88812.0, origem: 2703.0, carros: 4.0
# destino: 88814.0, origem: 2703.0, carros: 2.0
# destino: 88816.0, origem: 2715.0, carros: 3.0
# destino: 88818.0, origem: 2715.0, carros: 5.0
# destino: 88858.0, origem: 2715.0, carros: 1.0
# destino: 88859.0, origem: 2715.0, carros: 3.0
# destino: 88862.0, origem: 100.0, carros: 1.0
# destino: 88865.0, origem: 2715.0, carros: 1.0
# destino: 88868.0, origem: 100.0, carros: 1.0
# destino: 88904.0, origem: 2715.0, carros: 1.0
# destino: 88913.0, origem: 2715.0, carros: 3.0
# destino: 88927.0, origem: 100.0, carros: 1.0
# destino: 88950.0, origem: 100.0, carros: 1.0
# destino: 88958.0, origem: 2715.0, carros: 2.0
# destino: 88965.0, origem: 2715.0, carros: 2.0
# destino: 88980.0, origem: 2715.0, carros: 2.0
# destino: 88993.0, origem: 100.0, carros: 1.0
# destino: 89004.0, origem: 2715.0, carros: 2.0
# destino: 89024.0, origem: 100.0, carros: 1.0
# destino: 89027.0, origem: 2715.0, carros: 1.0
# destino: 89032.0, origem: 100.0, carros: 1.0
# destino: 89056.0, origem: 100.0, carros: 2.0
# destino: 89066.0, origem: 100.0, carros: 2.0
# destino: 89066.0, origem: 2703.0, carros: 3.0
# destino: 90591.0, origem: 100.0, carros: 2.0
# destino: 90777.0, origem: 100.0, carros: 1.0
# destino: 92942.0, origem: 2715.0, carros: 1.0
# destino: 93721.0, origem: 2715.0, carros: 1.0
# destino: 93723.0, origem: 100.0, carros: 1.0
# destino: 93726.0, origem: 100.0, carros: 2.0
# destino: 111097.0, origem: 2715.0, carros: 1.0
# destino: 111759.0, origem: 100.0, carros: 1.0
# destino: 112789.0, origem: 100.0, carros: 3.0
# destino: 114017.0, origem: 2715.0, carros: 2.0
# destino: 114021.0, origem: 2715.0, carros: 10.0
# destino: 114022.0, origem: 2715.0, carros: 4.0
# destino: 114025.0, origem: 2715.0, carros: 2.0
# destino: 114044.0, origem: 2715.0, carros: 1.0
# destino: 114074.0, origem: 100.0, carros: 4.0
# destino: 114253.0, origem: 2715.0, carros: 1.0
# destino: 114254.0, origem: 100.0, carros: 2.0
# destino: 116363.0, origem: 100.0, carros: 1.0
# destino: 116366.0, origem: 100.0, carros: 3.0
# destino: 118723.0, origem: 100.0, carros: 3.0
# destino: 118724.0, origem: 100.0, carros: 6.0
# destino: 118725.0, origem: 100.0, carros: 3.0
# destino: 127344.0, origem: 100.0, carros: 5.0
# destino: 127346.0, origem: 100.0, carros: 5.0
# destino: 127347.0, origem: 2715.0, carros: 1.0
# destino: 127352.0, origem: 100.0, carros: 1.0
# destino: 127356.0, origem: 2715.0, carros: 2.0
# destino: 127364.0, origem: 2703.0, carros: 5.0
# destino: 127365.0, origem: 2715.0, carros: 4.0
# destino: 127366.0, origem: 2715.0, carros: 2.0
# destino: 127367.0, origem: 2715.0, carros: 3.0
# destino: 127451.0, origem: 100.0, carros: 3.0
# destino: 127533.0, origem: 100.0, carros: 3.0
# destino: 128423.0, origem: 100.0, carros: 4.0
# destino: 128622.0, origem: 2703.0, carros: 8.0
# destino: 128625.0, origem: 2703.0, carros: 5.0
# destino: 129325.0, origem: 100.0, carros: 6.0
# destino: 129737.0, origem: 2715.0, carros: 3.0
# destino: 129738.0, origem: 2703.0, carros: 1.0
# destino: 129739.0, origem: 2715.0, carros: 1.0
# destino: 129755.0, origem: 2715.0, carros: 2.0
# destino: 129818.0, origem: 2715.0, carros: 5.0
# destino: 129849.0, origem: 100.0, carros: 1.0
# destino: 130739.0, origem: 2703.0, carros: 1.0
# destino: 130808.0, origem: 100.0, carros: 1.0
# destino: 132099.0, origem: 100.0, carros: 1.0
# destino: 134732.0, origem: 2703.0, carros: 2.0
# destino: 138690.0, origem: 100.0, carros: 4.0
# destino: 138691.0, origem: 100.0, carros: 3.0
# destino: 138695.0, origem: 2715.0, carros: 5.0
# destino: 138699.0, origem: 2703.0, carros: 2.0
# destino: 138702.0, origem: 100.0, carros: 5.0
# destino: 138703.0, origem: 100.0, carros: 5.0
# destino: 139479.0, origem: 100.0, carros: 1.0
# destino: 139480.0, origem: 100.0, carros: 4.0
# destino: 140091.0, origem: 2715.0, carros: 3.0
# destino: 143447.0, origem: 100.0, carros: 1.0
# destino: 146664.0, origem: 100.0, carros: 4.0
# destino: 146696.0, origem: 2715.0, carros: 7.0
# destino: 146954.0, origem: 100.0, carros: 2.0
# destino: 146958.0, origem: 2715.0, carros: 4.0
# destino: 146959.0, origem: 2715.0, carros: 1.0
# destino: 146978.0, origem: 100.0, carros: 4.0
# destino: 146984.0, origem: 2715.0, carros: 2.0
# destino: 147005.0, origem: 2703.0, carros: 4.0
# destino: 147014.0, origem: 2715.0, carros: 1.0
# destino: 147016.0, origem: 100.0, carros: 7.0
# destino: 147020.0, origem: 100.0, carros: 7.0
# destino: 147050.0, origem: 100.0, carros: 15.0
# destino: 147051.0, origem: 100.0, carros: 4.0
# destino: 147053.0, origem: 100.0, carros: 2.0
# destino: 147204.0, origem: 2715.0, carros: 3.0
# destino: 147205.0, origem: 2715.0, carros: 3.0
# destino: 147207.0, origem: 2703.0, carros: 2.0
# destino: 147210.0, origem: 100.0, carros: 12.0
# destino: 147222.0, origem: 2703.0, carros: 5.0
# destino: 147223.0, origem: 100.0, carros: 4.0
# destino: 147225.0, origem: 100.0, carros: 4.0
# destino: 147227.0, origem: 100.0, carros: 8.0
# destino: 147878.0, origem: 100.0, carros: 6.0
# destino: 148419.0, origem: 100.0, carros: 4.0
# destino: 148420.0, origem: 2715.0, carros: 2.0
# destino: 149276.0, origem: 100.0, carros: 1.0
# destino: 149284.0, origem: 100.0, carros: 2.0
# destino: 149287.0, origem: 100.0, carros: 7.0
# destino: 150086.0, origem: 100.0, carros: 1.0
# destino: 150091.0, origem: 2715.0, carros: 2.0
# destino: 150560.0, origem: 100.0, carros: 3.0
# destino: 150564.0, origem: 2703.0, carros: 1.0
# destino: 150565.0, origem: 2715.0, carros: 3.0
# destino: 150608.0, origem: 100.0, carros: 1.0
# destino: 150609.0, origem: 100.0, carros: 5.0
# destino: 150610.0, origem: 2703.0, carros: 3.0
# destino: 151113.0, origem: 100.0, carros: 1.0
# destino: 151164.0, origem: 2715.0, carros: 2.0
# destino: 151165.0, origem: 2703.0, carros: 3.0
# destino: 154369.0, origem: 2703.0, carros: 1.0
# destino: 154758.0, origem: 2715.0, carros: 4.0
# destino: 154780.0, origem: 100.0, carros: 2.0
# destino: 156828.0, origem: 2715.0, carros: 2.0
# destino: 156971.0, origem: 100.0, carros: 1.0
# destino: 156977.0, origem: 2715.0, carros: 12.0
# destino: 156984.0, origem: 100.0, carros: 2.0
# destino: 156985.0, origem: 100.0, carros: 7.0
# destino: 157030.0, origem: 100.0, carros: 2.0
# destino: 157157.0, origem: 100.0, carros: 1.0
# destino: 190349.0, origem: 2715.0, carros: 1.0
# destino: 399350.0, origem: 100.0, carros: 4.0
# destino: 399452.0, origem: 100.0, carros: 2.0
# destino: 465969.0, origem: 100.0, carros: 12.0
# destino: 466262.0, origem: 100.0, carros: 1.0
# destino: 467441.0, origem: 2703.0, carros: 1.0
