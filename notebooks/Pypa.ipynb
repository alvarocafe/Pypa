# %% [markdown]
# # Pypa - Modelo de otimização de rotas de carros-pipa utilizando Python
#
# Para construir o modelo do problema de otimização, busca-se minimizar uma função objetivo $f(x)$,
#
# $min(f^T \cdot x) $
#
# sujeito a restrições do tipo
#
# $A \cdot x \leq b$
#
# sendo que $x = [x_1,x_2,...,x_n]$ são as variáveis do problema, $f = [c_1,c_2,...c_n]$ são os coeficientes da função objetivo, $A$ é uma matriz $n \times m$ e $b=[b_1,b_2,...,b_m]$ com $b_j \geq 0$.
#
# Caso em que cada destino pode receber apenas de uma origem.

# %%
from pulp import *

# %%
# Os arquivos eles estão na mesma na mesma pasta que os cadernos
ofertatxt = open('../dados/quixada_oferta.txt','r')
demandatxt = open('../dados/quixada_demanda.txt','r')
distanciastxt = open('../dados/quixada_distancias.txt','r')

# %%
mOferta = list(map(int,ofertatxt.read().split()))
mDemanda = list(map(int,demandatxt.read().split()))

# %%
mDistancias = list(distanciastxt.read().split())
for i in range(len(mDistancias)):
    mDistancias[i] = int(round(float(mDistancias[i].replace('.','').replace(',','.'))))

# %%
mDistancias
# Out:
# [43277,
#  14060,
#  29549,
#  54803,
#  25461,
#  9751,
#  49510,
#  20168,
#  4458,
#  55355,
#  26012,
#  10303,
#  51891,
#  22566,
#  23806,
#  36766,
#  6284,
#  21772,
#  39837,
#  10621,
#  26110,
#  48590,
#  19374,
#  29539,
#  25913,
#  14361,
#  30722,
#  43919,
#  14703,
#  30192,
#  47411,
#  34114,
#  42506,
#  37198,
#  12088,
#  21931,
#  38677,
#  13260,
#  21278,
#  53863,
#  44484,
#  53039,
#  54913,
#  37308,
#  41151,
#  34896,
#  24284,
#  34127,
#  69746,
#  58753,
#  62027,
#  42316,
#  16899,
#  22383,
#  43866,
#  18449,
#  21000,
#  44240,
#  18823,
#  21557,
#  45593,
#  26394,
#  30236,
#  52884,
#  25211,
#  26451,
#  42896,
#  13570,
#  12939,
#  44010,
#  14684,
#  14053,
#  39048,
#  8158,
#  16521,
#  9556,
#  22991,
#  37739,
#  17401,
#  13606,
#  28354,
#  18136,
#  14395,
#  29142,
#  19891,
#  13374,
#  29734,
#  38275,
#  12267,
#  27756,
#  42260,
#  11370,
#  19732,
#  49512,
#  36461,
#  40303,
#  64470,
#  54917,
#  58759,
#  40322,
#  30942,
#  40785,
#  48222,
#  38843,
#  48686,
#  59910,
#  48574,
#  51444,
#  43616,
#  18199,
#  19926,
#  41619,
#  16202,
#  21815,
#  49258,
#  18367,
#  26730,
#  21393,
#  11872,
#  28232,
#  38976,
#  12968,
#  28457,
#  51267,
#  39931,
#  43773,
#  43250,
#  22222,
#  27536,
#  42925,
#  13709,
#  29133,
#  18232,
#  13551,
#  28298,
#  37104,
#  17049,
#  26891,
#  38356,
#  9140,
#  24629,
#  76794,
#  26574,
#  46260,
#  47780,
#  26413,
#  27653,
#  34384,
#  8686,
#  20618,
#  46398,
#  37019,
#  46861,
#  40551,
#  22207,
#  28662,
#  35122,
#  6207,
#  18139,
#  4211,
#  28660,
#  43407,
#  49457,
#  20241,
#  30406,
#  49199,
#  28632,
#  30283,
#  52026,
#  39344,
#  43186,
#  33313,
#  10077,
#  26151,
#  42390,
#  13064,
#  14305,
#  24804,
#  20144,
#  33021,
#  42890,
#  17474,
#  21818,
#  36380,
#  5490,
#  19185,
#  49959,
#  20743,
#  30908,
#  40830,
#  26428,
#  35824,
#  69829,
#  58835,
#  60529,
#  34828,
#  4346,
#  19835,
#  41244,
#  31865,
#  41707,
#  42913,
#  33533,
#  43376,
#  43692,
#  29291,
#  36757,
#  53686,
#  44306,
#  52134,
#  51269,
#  39933,
#  43775,
#  35846,
#  5363,
#  20852,
#  18071,
#  15194,
#  31554,
#  36801,
#  6319,
#  21808,
#  9421,
#  26289,
#  41111,
#  9345,
#  26237,
#  41036,
#  14461,
#  22929,
#  37676,
#  46483,
#  17157,
#  17613,
#  15767,
#  24235,
#  38983,
#  20185,
#  11598,
#  26345,
#  40399,
#  11056,
#  5608,
#  24683,
#  7606,
#  22353,
#  44912,
#  14022,
#  22385,
#  48608,
#  17717,
#  26080,
#  14032,
#  41712,
#  54589,
#  23508,
#  15148,
#  31508,
#  49911,
#  41149,
#  50992,
#  9143,
#  26086,
#  40834,
#  9811,
#  26371,
#  41501,
#  10122,
#  25461,
#  41690,
#  9751,
#  25924,
#  41441,
#  3313,
#  27674,
#  42421,
#  49035,
#  18145,
#  26508,
#  44072,
#  30775,
#  40170,
#  34893,
#  9476,
#  21408,
#  35272,
#  9856,
#  21236,
#  43472,
#  18210,
#  21450,
#  46480,
#  15590,
#  23952,
#  48294,
#  19077,
#  28528,
#  52122,
#  34517,
#  38359,
#  27127,
#  16828,
#  29705,
#  56045,
#  26720,
#  11468,
#  30951,
#  10764,
#  27124,
#  36374,
#  7049,
#  13374,
#  42793,
#  21766,
#  27079,
#  35251,
#  19474,
#  29316,
#  17554,
#  26319,
#  39196,
#  48261,
#  17371,
#  25733,
#  52473,
#  23130,
#  7421,
#  52209,
#  22866,
#  6474,
#  49327,
#  33772,
#  37615,
#  48008,
#  19156,
#  20397,
#  46801,
#  33504,
#  39763,
#  48005,
#  19159,
#  20399,
#  46596,
#  37217,
#  44653,
#  7261,
#  33455,
#  48203,
#  94401,
#  70321,
#  87103,
#  16643,
#  27230,
#  40107,
#  69933,
#  58940,
#  61764,
#  38786,
#  8108,
#  13081,
#  51009,
#  21683,
#  22924,
#  39585,
#  18823,
#  34312,
#  28095,
#  6883,
#  23243,
#  51445,
#  22102,
#  6393,
#  13072,
#  20166,
#  34914,
#  24662,
#  7628,
#  22375,
#  48055,
#  18713,
#  6677,
#  46375,
#  15544,
#  23907,
#  49659,
#  20443,
#  30607,
#  44223,
#  13333,
#  21696,
#  49094,
#  18204,
#  26567,
#  36965,
#  32256,
#  42098,
#  43818,
#  19253,
#  21987,
#  14372,
#  22622,
#  38982,
#  14714,
#  29159,
#  42036,
#  14702,
#  29171,
#  42048,
#  40194,
#  30814,
#  40657,
#  41219,
#  31840,
#  41682,
#  50231,
#  40852,
#  50694,
#  9409,
#  26352,
#  41100,
#  25563,
#  16128,
#  32488,
#  48442,
#  20012,
#  21252,
#  52242,
#  38524,
#  42367,
#  39139,
#  8248,
#  16611,
#  44443,
#  15226,
#  30715,
#  39146,
#  14036,
#  23879,
#  39220,
#  14427,
#  24269,
#  44551,
#  13661,
#  22024,
#  14702,
#  29171,
#  42048,
#  47818,
#  39057,
#  48899,
#  38341,
#  19656,
#  35145,
#  42791,
#  13575,
#  27491,
#  86821,
#  28389,
#  54488,
#  10208,
#  40416,
#  53293,
#  40607,
#  9717,
#  18080,
#  42433,
#  13217,
#  28706,
#  49119,
#  18229,
#  26592,
#  36172,
#  6830,
#  10117,
#  44948,
#  23920,
#  28349,
#  27314,
#  12961,
#  29321,
#  39583,
#  10367,
#  25855,
#  14140,
#  42284,
#  55161,
#  5413,
#  36400,
#  51148,
#  35847,
#  6933,
#  18864,
#  13030,
#  33842,
#  46719,
#  4442,
#  26544,
#  41292,
#  50539,
#  21323,
#  31488,
#  42047,
#  12831,
#  28320,
#  25781,
#  11316,
#  27676,
#  26440,
#  10768,
#  27128,
#  51289,
#  39953,
#  43796,
#  5829,
#  32023,
#  46771,
#  46053,
#  15163,
#  23525,
#  47672,
#  38292,
#  44879,
#  47057,
#  35303,
#  43694,
#  38822,
#  15579,
#  25422,
#  46534,
#  37155,
#  46997,
#  45130,
#  15913,
#  25892,
#  44968,
#  15752,
#  25529,
#  10732,
#  36926,
#  51674,
#  39244,
#  14403,
#  24246,
#  34728,
#  9247,
#  24736,
#  40857,
#  9967,
#  18329,
#  34531,
#  19874,
#  29716,
#  31529,
#  21230,
#  33794,
#  8829,
#  35024,
#  49771,
#  11052,
#  37246,
#  51994,
#  47769,
#  39007,
#  48850,
#  37686,
#  6796,
#  15143,
#  40923,
#  10033,
#  18396,
#  35945,
#  8030,
#  23519,
#  35144,
#  20487,
#  30330,
#  76688,
#  39318,
#  70295,
#  38345,
#  19651,
#  35140,
#  39484,
#  20762,
#  36250,
#  39484,
#  20762,
#  36250,
#  45344,
#  28761,
#  61482,
#  48829,
#  35209,
#  39051,
#  45157,
#  15941,
#  25340,
#  18714,
#  26365,
#  39242,
#  15649,
#  35525,
#  48402,
#  12923,
#  36334,
#  49211,
#  27776,
#  10332,
#  23400,
#  59829,
#  45097,
#  46781,
#  45251,
#  35872,
#  45714,
#  30479,
#  3183,
#  19544,
#  35530,
#  6187,
#  10204,
#  51255,
#  39919,
#  43761,
#  55026,
#  42934,
#  46776,
#  39260,
#  10044,
#  25533,
#  38049,
#  32711,
#  42553,
#  46340,
#  15450,
#  23813,
#  46447,
#  17230,
#  32719,
#  36363,
#  5880,
#  19623,
#  54225,
#  24900,
#  13401,
#  23047,
#  7939,
#  22687,
#  53463,
#  24137,
#  8886,
#  51914,
#  42535,
#  46900,
#  34539,
#  5197,
#  11463,
#  15748,
#  38427,
#  51304,
#  7253,
#  29267,
#  44014,
#  14714,
#  29159,
#  42036,
#  51953,
#  41179,
#  45022,
#  51399,
#  20509,
#  28871,
#  19657,
#  15916,
#  30663,
#  23222,
#  9067,
#  23815,
#  19871,
#  51294,
#  83253,
#  25115,
#  11154,
#  27514,
#  36461,
#  8924,
#  24413]

# %%
# Agora vamos construir a matriz de distâncias
cont = 0
ldemanda = []
Distancias =[]
# Os valores serão adicionados linha a linha
for i in range(len(mDemanda)):
    for j in range(len(mOferta)):
        ldemanda.append(mDistancias[cont])
        cont += 1
    Distancias.append(ldemanda)
    ldemanda = []
ofertatxt.close()
demandatxt.close()
distanciastxt.close()

# %%
Distancias
# Out:
# [[43277, 14060, 29549],
#  [54803, 25461, 9751],
#  [49510, 20168, 4458],
#  [55355, 26012, 10303],
#  [51891, 22566, 23806],
#  [36766, 6284, 21772],
#  [39837, 10621, 26110],
#  [48590, 19374, 29539],
#  [25913, 14361, 30722],
#  [43919, 14703, 30192],
#  [47411, 34114, 42506],
#  [37198, 12088, 21931],
#  [38677, 13260, 21278],
#  [53863, 44484, 53039],
#  [54913, 37308, 41151],
#  [34896, 24284, 34127],
#  [69746, 58753, 62027],
#  [42316, 16899, 22383],
#  [43866, 18449, 21000],
#  [44240, 18823, 21557],
#  [45593, 26394, 30236],
#  [52884, 25211, 26451],
#  [42896, 13570, 12939],
#  [44010, 14684, 14053],
#  [39048, 8158, 16521],
#  [9556, 22991, 37739],
#  [17401, 13606, 28354],
#  [18136, 14395, 29142],
#  [19891, 13374, 29734],
#  [38275, 12267, 27756],
#  [42260, 11370, 19732],
#  [49512, 36461, 40303],
#  [64470, 54917, 58759],
#  [40322, 30942, 40785],
#  [48222, 38843, 48686],
#  [59910, 48574, 51444],
#  [43616, 18199, 19926],
#  [41619, 16202, 21815],
#  [49258, 18367, 26730],
#  [21393, 11872, 28232],
#  [38976, 12968, 28457],
#  [51267, 39931, 43773],
#  [43250, 22222, 27536],
#  [42925, 13709, 29133],
#  [18232, 13551, 28298],
#  [37104, 17049, 26891],
#  [38356, 9140, 24629],
#  [76794, 26574, 46260],
#  [47780, 26413, 27653],
#  [34384, 8686, 20618],
#  [46398, 37019, 46861],
#  [40551, 22207, 28662],
#  [35122, 6207, 18139],
#  [4211, 28660, 43407],
#  [49457, 20241, 30406],
#  [49199, 28632, 30283],
#  [52026, 39344, 43186],
#  [33313, 10077, 26151],
#  [42390, 13064, 14305],
#  [24804, 20144, 33021],
#  [42890, 17474, 21818],
#  [36380, 5490, 19185],
#  [49959, 20743, 30908],
#  [40830, 26428, 35824],
#  [69829, 58835, 60529],
#  [34828, 4346, 19835],
#  [41244, 31865, 41707],
#  [42913, 33533, 43376],
#  [43692, 29291, 36757],
#  [53686, 44306, 52134],
#  [51269, 39933, 43775],
#  [35846, 5363, 20852],
#  [18071, 15194, 31554],
#  [36801, 6319, 21808],
#  [9421, 26289, 41111],
#  [9345, 26237, 41036],
#  [14461, 22929, 37676],
#  [46483, 17157, 17613],
#  [15767, 24235, 38983],
#  [20185, 11598, 26345],
#  [40399, 11056, 5608],
#  [24683, 7606, 22353],
#  [44912, 14022, 22385],
#  [48608, 17717, 26080],
#  [14032, 41712, 54589],
#  [23508, 15148, 31508],
#  [49911, 41149, 50992],
#  [9143, 26086, 40834],
#  [9811, 26371, 41501],
#  [10122, 25461, 41690],
#  [9751, 25924, 41441],
#  [3313, 27674, 42421],
#  [49035, 18145, 26508],
#  [44072, 30775, 40170],
#  [34893, 9476, 21408],
#  [35272, 9856, 21236],
#  [43472, 18210, 21450],
#  [46480, 15590, 23952],
#  [48294, 19077, 28528],
#  [52122, 34517, 38359],
#  [27127, 16828, 29705],
#  [56045, 26720, 11468],
#  [30951, 10764, 27124],
#  [36374, 7049, 13374],
#  [42793, 21766, 27079],
#  [35251, 19474, 29316],
#  [17554, 26319, 39196],
#  [48261, 17371, 25733],
#  [52473, 23130, 7421],
#  [52209, 22866, 6474],
#  [49327, 33772, 37615],
#  [48008, 19156, 20397],
#  [46801, 33504, 39763],
#  [48005, 19159, 20399],
#  [46596, 37217, 44653],
#  [7261, 33455, 48203],
#  [94401, 70321, 87103],
#  [16643, 27230, 40107],
#  [69933, 58940, 61764],
#  [38786, 8108, 13081],
#  [51009, 21683, 22924],
#  [39585, 18823, 34312],
#  [28095, 6883, 23243],
#  [51445, 22102, 6393],
#  [13072, 20166, 34914],
#  [24662, 7628, 22375],
#  [48055, 18713, 6677],
#  [46375, 15544, 23907],
#  [49659, 20443, 30607],
#  [44223, 13333, 21696],
#  [49094, 18204, 26567],
#  [36965, 32256, 42098],
#  [43818, 19253, 21987],
#  [14372, 22622, 38982],
#  [14714, 29159, 42036],
#  [14702, 29171, 42048],
#  [40194, 30814, 40657],
#  [41219, 31840, 41682],
#  [50231, 40852, 50694],
#  [9409, 26352, 41100],
#  [25563, 16128, 32488],
#  [48442, 20012, 21252],
#  [52242, 38524, 42367],
#  [39139, 8248, 16611],
#  [44443, 15226, 30715],
#  [39146, 14036, 23879],
#  [39220, 14427, 24269],
#  [44551, 13661, 22024],
#  [14702, 29171, 42048],
#  [47818, 39057, 48899],
#  [38341, 19656, 35145],
#  [42791, 13575, 27491],
#  [86821, 28389, 54488],
#  [10208, 40416, 53293],
#  [40607, 9717, 18080],
#  [42433, 13217, 28706],
#  [49119, 18229, 26592],
#  [36172, 6830, 10117],
#  [44948, 23920, 28349],
#  [27314, 12961, 29321],
#  [39583, 10367, 25855],
#  [14140, 42284, 55161],
#  [5413, 36400, 51148],
#  [35847, 6933, 18864],
#  [13030, 33842, 46719],
#  [4442, 26544, 41292],
#  [50539, 21323, 31488],
#  [42047, 12831, 28320],
#  [25781, 11316, 27676],
#  [26440, 10768, 27128],
#  [51289, 39953, 43796],
#  [5829, 32023, 46771],
#  [46053, 15163, 23525],
#  [47672, 38292, 44879],
#  [47057, 35303, 43694],
#  [38822, 15579, 25422],
#  [46534, 37155, 46997],
#  [45130, 15913, 25892],
#  [44968, 15752, 25529],
#  [10732, 36926, 51674],
#  [39244, 14403, 24246],
#  [34728, 9247, 24736],
#  [40857, 9967, 18329],
#  [34531, 19874, 29716],
#  [31529, 21230, 33794],
#  [8829, 35024, 49771],
#  [11052, 37246, 51994],
#  [47769, 39007, 48850],
#  [37686, 6796, 15143],
#  [40923, 10033, 18396],
#  [35945, 8030, 23519],
#  [35144, 20487, 30330],
#  [76688, 39318, 70295],
#  [38345, 19651, 35140],
#  [39484, 20762, 36250],
#  [39484, 20762, 36250],
#  [45344, 28761, 61482],
#  [48829, 35209, 39051],
#  [45157, 15941, 25340],
#  [18714, 26365, 39242],
#  [15649, 35525, 48402],
#  [12923, 36334, 49211],
#  [27776, 10332, 23400],
#  [59829, 45097, 46781],
#  [45251, 35872, 45714],
#  [30479, 3183, 19544],
#  [35530, 6187, 10204],
#  [51255, 39919, 43761],
#  [55026, 42934, 46776],
#  [39260, 10044, 25533],
#  [38049, 32711, 42553],
#  [46340, 15450, 23813],
#  [46447, 17230, 32719],
#  [36363, 5880, 19623],
#  [54225, 24900, 13401],
#  [23047, 7939, 22687],
#  [53463, 24137, 8886],
#  [51914, 42535, 46900],
#  [34539, 5197, 11463],
#  [15748, 38427, 51304],
#  [7253, 29267, 44014],
#  [14714, 29159, 42036],
#  [51953, 41179, 45022],
#  [51399, 20509, 28871],
#  [19657, 15916, 30663],
#  [23222, 9067, 23815],
#  [19871, 51294, 83253],
#  [25115, 11154, 27514],
#  [36461, 8924, 24413]]

# %%
prob = LpProblem("mainPulp",LpMinimize)

# %%
Varx = LpVariable.dicts("Varx",[(i,j) for i in range(len(mDemanda)) for j in range(len(mOferta))],0,None,LpInteger)

# %%
# Objetivo
# Demanda[i][1]*
prob += lpSum(Distancias[i][j] * Varx[(i,j)] for i in range(len(mDemanda)) for j in range(len(mOferta)))

# %%
prob
# Out:
# mainPulp:
# MINIMIZE
# 43277*Varx_(0,_0) + 14060*Varx_(0,_1) + 29549*Varx_(0,_2) + 54803*Varx_(1,_0) + 25461*Varx_(1,_1) + 9751*Varx_(1,_2) + 47411*Varx_(10,_0) + 34114*Varx_(10,_1) + 42506*Varx_(10,_2) + 27127*Varx_(100,_0) + 16828*Varx_(100,_1) + 29705*Varx_(100,_2) + 56045*Varx_(101,_0) + 26720*Varx_(101,_1) + 11468*Varx_(101,_2) + 30951*Varx_(102,_0) + 10764*Varx_(102,_1) + 27124*Varx_(102,_2) + 36374*Varx_(103,_0) + 7049*Varx_(103,_1) + 13374*Varx_(103,_2) + 42793*Varx_(104,_0) + 21766*Varx_(104,_1) + 27079*Varx_(104,_2) + 35251*Varx_(105,_0) + 19474*Varx_(105,_1) + 29316*Varx_(105,_2) + 17554*Varx_(106,_0) + 26319*Varx_(106,_1) + 39196*Varx_(106,_2) + 48261*Varx_(107,_0) + 17371*Varx_(107,_1) + 25733*Varx_(107,_2) + 52473*Varx_(108,_0) + 23130*Varx_(108,_1) + 7421*Varx_(108,_2) + 52209*Varx_(109,_0) + 22866*Varx_(109,_1) + 6474*Varx_(109,_2) + 37198*Varx_(11,_0) + 12088*Varx_(11,_1) + 21931*Varx_(11,_2) + 49327*Varx_(110,_0) + 33772*Varx_(110,_1) + 37615*Varx_(110,_2) + 48008*Varx_(111,_0) + 19156*Varx_(111,_1) + 20397*Varx_(111,_2) + 46801*Varx_(112,_0) + 33504*Varx_(112,_1) + 39763*Varx_(112,_2) + 48005*Varx_(113,_0) + 19159*Varx_(113,_1) + 20399*Varx_(113,_2) + 46596*Varx_(114,_0) + 37217*Varx_(114,_1) + 44653*Varx_(114,_2) + 7261*Varx_(115,_0) + 33455*Varx_(115,_1) + 48203*Varx_(115,_2) + 94401*Varx_(116,_0) + 70321*Varx_(116,_1) + 87103*Varx_(116,_2) + 16643*Varx_(117,_0) + 27230*Varx_(117,_1) + 40107*Varx_(117,_2) + 69933*Varx_(118,_0) + 58940*Varx_(118,_1) + 61764*Varx_(118,_2) + 38786*Varx_(119,_0) + 8108*Varx_(119,_1) + 13081*Varx_(119,_2) + 38677*Varx_(12,_0) + 13260*Varx_(12,_1) + 21278*Varx_(12,_2) + 51009*Varx_(120,_0) + 21683*Varx_(120,_1) + 22924*Varx_(120,_2) + 39585*Varx_(121,_0) + 18823*Varx_(121,_1) + 34312*Varx_(121,_2) + 28095*Varx_(122,_0) + 6883*Varx_(122,_1) + 23243*Varx_(122,_2) + 51445*Varx_(123,_0) + 22102*Varx_(123,_1) + 6393*Varx_(123,_2) + 13072*Varx_(124,_0) + 20166*Varx_(124,_1) + 34914*Varx_(124,_2) + 24662*Varx_(125,_0) + 7628*Varx_(125,_1) + 22375*Varx_(125,_2) + 48055*Varx_(126,_0) + 18713*Varx_(126,_1) + 6677*Varx_(126,_2) + 46375*Varx_(127,_0) + 15544*Varx_(127,_1) + 23907*Varx_(127,_2) + 49659*Varx_(128,_0) + 20443*Varx_(128,_1) + 30607*Varx_(128,_2) + 44223*Varx_(129,_0) + 13333*Varx_(129,_1) + 21696*Varx_(129,_2) + 53863*Varx_(13,_0) + 44484*Varx_(13,_1) + 53039*Varx_(13,_2) + 49094*Varx_(130,_0) + 18204*Varx_(130,_1) + 26567*Varx_(130,_2) + 36965*Varx_(131,_0) + 32256*Varx_(131,_1) + 42098*Varx_(131,_2) + 43818*Varx_(132,_0) + 19253*Varx_(132,_1) + 21987*Varx_(132,_2) + 14372*Varx_(133,_0) + 22622*Varx_(133,_1) + 38982*Varx_(133,_2) + 14714*Varx_(134,_0) + 29159*Varx_(134,_1) + 42036*Varx_(134,_2) + 14702*Varx_(135,_0) + 29171*Varx_(135,_1) + 42048*Varx_(135,_2) + 40194*Varx_(136,_0) + 30814*Varx_(136,_1) + 40657*Varx_(136,_2) + 41219*Varx_(137,_0) + 31840*Varx_(137,_1) + 41682*Varx_(137,_2) + 50231*Varx_(138,_0) + 40852*Varx_(138,_1) + 50694*Varx_(138,_2) + 9409*Varx_(139,_0) + 26352*Varx_(139,_1) + 41100*Varx_(139,_2) + 54913*Varx_(14,_0) + 37308*Varx_(14,_1) + 41151*Varx_(14,_2) + 25563*Varx_(140,_0) + 16128*Varx_(140,_1) + 32488*Varx_(140,_2) + 48442*Varx_(141,_0) + 20012*Varx_(141,_1) + 21252*Varx_(141,_2) + 52242*Varx_(142,_0) + 38524*Varx_(142,_1) + 42367*Varx_(142,_2) + 39139*Varx_(143,_0) + 8248*Varx_(143,_1) + 16611*Varx_(143,_2) + 44443*Varx_(144,_0) + 15226*Varx_(144,_1) + 30715*Varx_(144,_2) + 39146*Varx_(145,_0) + 14036*Varx_(145,_1) + 23879*Varx_(145,_2) + 39220*Varx_(146,_0) + 14427*Varx_(146,_1) + 24269*Varx_(146,_2) + 44551*Varx_(147,_0) + 13661*Varx_(147,_1) + 22024*Varx_(147,_2) + 14702*Varx_(148,_0) + 29171*Varx_(148,_1) + 42048*Varx_(148,_2) + 47818*Varx_(149,_0) + 39057*Varx_(149,_1) + 48899*Varx_(149,_2) + 34896*Varx_(15,_0) + 24284*Varx_(15,_1) + 34127*Varx_(15,_2) + 38341*Varx_(150,_0) + 19656*Varx_(150,_1) + 35145*Varx_(150,_2) + 42791*Varx_(151,_0) + 13575*Varx_(151,_1) + 27491*Varx_(151,_2) + 86821*Varx_(152,_0) + 28389*Varx_(152,_1) + 54488*Varx_(152,_2) + 10208*Varx_(153, ...
# VARIABLES
# 0 <= Varx_(0,_0) Integer
# 0 <= Varx_(0,_1) Integer
# 0 <= Varx_(0,_2) Integer
# 0 <= Varx_(1,_0) Integer
# 0 <= Varx_(1,_1) Integer
# 0 <= Varx_(1,_2) Integer
# 0 <= Varx_(10,_0) Integer
# 0 <= Varx_(10,_1) Integer
# 0 <= Varx_(10,_2) Integer
# 0 <= Varx_(100,_0) Integer
# 0 <= Varx_(100,_1) Integer
# 0 <= Varx_(100,_2) Integer
# 0 <= Varx_(101,_0) Integer
# 0 <= Varx_(101,_1) Integer
# 0 <= Varx_(101,_2) Integer
# 0 <= Varx_(102,_0) Integer
# 0 <= Varx_(102,_1) Integer
# 0 <= Varx_(102,_2) Integer
# 0 <= Varx_(103,_0) Integer
# 0 <= Varx_(103,_1) Integer
# 0 <= Varx_(103,_2) Integer
# 0 <= Varx_(104,_0) Integer
# 0 <= Varx_(104,_1) Integer
# 0 <= Varx_(104,_2) Integer
# 0 <= Varx_(105,_0) Integer
# 0 <= Varx_(105,_1) Integer
# 0 <= Varx_(105,_2) Integer
# 0 <= Varx_(106,_0) Integer
# 0 <= Varx_(106,_1) Integer
# 0 <= Varx_(106,_2) Integer
# 0 <= Varx_(107,_0) Integer
# 0 <= Varx_(107,_1) Integer
# 0 <= Varx_(107,_2) Integer
# 0 <= Varx_(108,_0) Integer
# 0 <= Varx_(108,_1) Integer
# 0 <= Varx_(108,_2) Integer
# 0 <= Varx_(109,_0) Integer
# 0 <= Varx_(109,_1) Integer
# 0 <= Varx_(109,_2) Integer
# 0 <= Varx_(11,_0) Integer
# 0 <= Varx_(11,_1) Integer
# 0 <= Varx_(11,_2) Integer
# 0 <= Varx_(110,_0) Integer
# 0 <= Varx_(110,_1) Integer
# 0 <= Varx_(110,_2) Integer
# 0 <= Varx_(111,_0) Integer
# 0 <= Varx_(111,_1) Integer
# 0 <= Varx_(111,_2) Integer
# 0 <= Varx_(112,_0) Integer
# 0 <= Varx_(112,_1) Integer
# 0 <= Varx_(112,_2) Integer
# 0 <= Varx_(113,_0) Integer
# 0 <= Varx_(113,_1) Integer
# 0 <= Varx_(113,_2) Integer
# 0 <= Varx_(114,_0) Integer
# 0 <= Varx_(114,_1) Integer
# 0 <= Varx_(114,_2) Integer
# 0 <= Varx_(115,_0) Integer
# 0 <= Varx_(115,_1) Integer
# 0 <= Varx_(115,_2) Integer
# 0 <= Varx_(116,_0) Integer
# 0 <= Varx_(116,_1) Integer
# 0 <= Varx_(116,_2) Integer
# 0 <= Varx_(117,_0) Integer
# 0 <= Varx_(117,_1) Integer
# 0 <= Varx_(117,_2) Integer
# 0 <= Varx_(118,_0) Integer
# 0 <= Varx_(118,_1) Integer
# 0 <= Varx_(118,_2) Integer
# 0 <= Varx_(119,_0) Integer
# 0 <= Varx_(119,_1) Integer
# 0 <= Varx_(119,_2) Integer
# 0 <= Varx_(12,_0) Integer
# 0 <= Varx_(12,_1) Integer
# 0 <= Varx_(12,_2) Integer
# 0 <= Varx_(120,_0) Integer
# 0 <= Varx_(120,_1) Integer
# 0 <= Varx_(120,_2) Integer
# 0 <= Varx_(121,_0) Integer
# 0 <= Varx_(121,_1) Integer
# 0 <= Varx_(121,_2) Integer
# 0 <= Varx_(122,_0) Integer
# 0 <= Varx_(122,_1) Integer
# 0 <= Varx_(122,_2) Integer
# 0 <= Varx_(123,_0) Integer
# 0 <= Varx_(123,_1) Integer
# 0 <= Varx_(123,_2) Integer
# 0 <= Varx_(124,_0) Integer
# 0 <= Varx_(124,_1) Integer
# 0 <= Varx_(124,_2) Integer
# 0 <= Varx_(125,_0) Integer
# 0 <= Varx_(125,_1) Integer
# 0 <= Varx_(125,_2) Integer
# 0 <= Varx_(126,_0) Integer
# 0 <= Varx_(126,_1) Integer
# 0 <= Varx_(126,_2) Integer
# 0 <= Varx_(127,_0) Integer
# 0 <= Varx_(127,_1) Integer
# 0 <= Varx_(127,_2) Integer
# 0 <= Varx_(128,_0) Integer
# 0 <= Varx_(128,_1) Integer
# 0 <= Varx_(128,_2) Integer
# 0 <= Varx_(129,_0) Integer
# 0 <= Varx_(129,_1) Integer
# 0 <= Varx_(129,_2) Integer
# 0 <= Varx_(13,_0) Integer
# 0 <= Varx_(13,_1) Integer
# 0 <= Varx_(13,_2) Integer
# 0 <= Varx_(130,_0) Integer
# 0 <= Varx_(130,_1) Integer
# 0 <= Varx_(130,_2) Integer
# 0 <= Varx_(131,_0) Integer
# 0 <= Varx_(131,_1) Integer
# 0 <= Varx_(131,_2) Integer
# 0 <= Varx_(132,_0) Integer
# 0 <= Varx_(132,_1) Integer
# 0 <= Varx_(132,_2) Integer
# 0 <= Varx_(133,_0) Integer
# 0 <= Varx_(133,_1) Integer
# 0 <= Varx_(133,_2) Integer
# 0 <= Varx_(134,_0) Integer
# 0 <= Varx_(134,_1) Integer
# 0 <= Varx_(134,_2) Integer
# 0 <= Varx_(135,_0) Integer
# 0 <= Varx_(135,_1) Integer
# 0 <= Varx_(135,_2) Integer
# 0 <= Varx_(136,_0) Integer
# 0 <= Varx_(136,_1) Integer
# 0 <= Varx_(136,_2) Integer
# 0 <= Varx_(137,_0) Integer
# 0 <= Varx_(137,_1) Integer
# 0 <= Varx_(137,_2) Integer
# 0 <= Varx_(138,_0) Integer
# 0 <= Varx_(138,_1) Integer
# 0 <= Varx_(138,_2) Integer
# 0 <= Varx_(139,_0) Integer
# 0 <= Varx_(139,_1) Integer
# 0 <= Varx_(139,_2) Integer
# 0 <= Varx_(14,_0) Integer
# 0 <= Varx_(14,_1) Integer
# 0 <= Varx_(14,_2) Integer
# 0 <= Varx_(140,_0) Integer
# 0 <= Varx_(140,_1) Integer
# 0 <= Varx_(140,_2) Integer
# 0 <= Varx_(141,_0) Integer
# 0 <= Varx_(141,_1) Integer
# 0 <= Varx_(141,_2) Integer
# 0 <= Varx_(142,_0) Integer
# 0 <= Varx_(142,_1) Integer
# 0 <= Varx_(142,_2) Integer
# 0 <= Varx_(143,_0) Integer
# 0 <= Varx_(143,_1) Integer
# 0 <= Varx_(143,_2) Integer
# 0 <= Varx_(144,_0) Integer
# 0 <= Varx_(144,_1) Integer
# 0 <= Varx_(144,_2) Integer
# 0 <= Varx_(145,_0) Integer
# 0 <= Varx_(145,_1) Integer
# 0 <= Varx_(145,_2) Integer
# 0 <= Varx_(146,_0) Integer
# 0 <= Varx_(146,_1) Integer
# 0 <= Varx_(146,_2) Integer
# 0 <= Varx_(147,_0) Integer
# 0 <= Varx_(147,_1) Integer
# 0 <= Varx_(147,_2) Integer
# 0 <= Varx_(148,_0) Integer
# 0 <= Varx_(148,_1) Integer
# 0 <= Varx_(148,_2) Integer
# 0 <= Varx_(149,_0) Integer
# 0 <= Varx_(149,_1) Integer
# 0 <= Varx_(149,_2) Integer
# 0 <= Varx_(15,_0) Integer
# 0 <= Varx_(15,_1) Integer
# 0 <= Varx_(15,_2) Integer
# 0 <= Varx_(150,_0) Integer
# 0 <= Varx_(150,_1) Integer
# 0 <= Varx_(150,_2) Integer
# 0 <= Varx_(151,_0) Integer
# 0 <= Varx_(151,_1) Integer
# 0 <= Varx_(151,_2) Integer
# 0 <= Varx_(152,_0) Integer
# 0 <= Varx_(152,_1) Integer
# 0 <= Varx_(152,_2) Integer
# 0 <= Varx_(153,_0) Integer
# 0 <= Varx_(153,_1) Integer
# 0 <= Varx_(153,_2) Integer
# 0 <= Varx_(154,_0) Integer
# 0 <= Varx_(154,_1) Integer
# 0 <= Varx_(154,_2) Integer
# 0 <= Varx_(155,_0) Integer
# 0 <= Varx_(155,_1) Integer
# 0 <= Varx_(155,_2) Integer
# 0 <= Varx_(156,_0) Integer
# 0 <= Varx_(156,_1) Integer
# 0 <= Varx_(156,_2) Integer
# 0 <= Varx_(157,_0) Integer
# 0 <= Varx_(157,_1) Integer
# 0 <= Varx_(157,_2) Integer
# 0 <= Varx_(158,_0) Integer
# 0 <= Varx_(158,_1) Integer
# 0 <= Varx_(158,_2) Integer
# 0 <= Varx_(159,_0) Integer
# 0 <= Varx_(159,_1) Integer
# 0 <= Varx_(159,_2) Integer
# 0 <= Varx_(16,_0) Integer
# 0 <= Varx_(16,_1) Integer
# 0 <= Varx_(16,_2) Integer
# 0 <= Varx_(160,_0) Integer
# 0 <= Varx_(160,_1) Integer
# 0 <= Varx_(160,_2) Integer
# 0 <= Varx_(161,_0) Integer
# 0 <= Varx_(161,_1) Integer
# 0 <= Varx_(161,_2) Integer
# 0 <= Varx_(162,_0) Integer
# 0 <= Varx_(162,_1) Integer
# 0 <= Varx_(162,_2) Integer
# 0 <= Varx_(163,_0) Integer
# 0 <= Varx_(163,_1) Integer
# 0 <= Varx_(163,_2) Integer
# 0 <= Varx_(164,_0) Integer
# 0 <= Varx_(164,_1) Integer
# 0 <= Varx_(164,_2) Integer
# 0 <= Varx_(165,_0) Integer
# 0 <= Varx_(165,_1) Integer
# 0 <= Varx_(165,_2) Integer
# 0 <= Varx_(166,_0) Integer
# 0 <= Varx_(166,_1) Integer
# 0 <= Varx_(166,_2) Integer
# 0 <= Varx_(167,_0) Integer
# 0 <= Varx_(167,_1) Integer
# 0 <= Varx_(167,_2) Integer
# 0 <= Varx_(168,_0) Integer
# 0 <= Varx_(168,_1) Integer
# 0 <= Varx_(168,_2) Integer
# 0 <= Varx_(169,_0) Integer
# 0 <= Varx_(169,_1) Integer
# 0 <= Varx_(169,_2) Integer
# 0 <= Varx_(17,_0) Integer
# 0 <= Varx_(17,_1) Integer
# 0 <= Varx_(17,_2) Integer
# 0 <= Varx_(170,_0) Integer
# 0 <= Varx_(170,_1) Integer
# 0 <= Varx_(170,_2) Integer
# 0 <= Varx_(171,_0) Integer
# 0 <= Varx_(171,_1) Integer
# 0 <= Varx_(171,_2) Integer
# 0 <= Varx_(172,_0) Integer
# 0 <= Varx_(172,_1) Integer
# 0 <= Varx_(172,_2) Integer
# 0 <= Varx_(173,_0) Integer
# 0 <= Varx_(173,_1) Integer
# 0 <= Varx_(173,_2) Integer
# 0 <= Varx_(174,_0) Integer
# 0 <= Varx_(174,_1) Integer
# 0 <= Varx_(174,_2) Integer
# 0 <= Varx_(175,_0) Integer
# 0 <= Varx_(175,_1) Integer
# 0 <= Varx_(175,_2) Integer
# 0 <= Varx_(176,_0) Integer
# 0 <= Varx_(176,_1) Integer
# 0 <= Varx_(176,_2) Integer
# 0 <= Varx_(177,_0) Integer
# 0 <= Varx_(177,_1) Integer
# 0 <= Varx_(177,_2) Integer
# 0 <= Varx_(178,_0) Integer
# 0 <= Varx_(178,_1) Integer
# 0 <= Varx_(178,_2) Integer
# 0 <= Varx_(179,_0) Integer
# 0 <= Varx_(179,_1) Integer
# 0 <= Varx_(179,_2) Integer
# 0 <= Varx_(18,_0) Integer
# 0 <= Varx_(18,_1) Integer
# 0 <= Varx_(18,_2) Integer
# 0 <= Varx_(180,_0) Integer
# 0 <= Varx_(180,_1) Integer
# 0 <= Varx_(180,_2) Integer
# 0 <= Varx_(181,_0) Integer
# 0 <= Varx_(181,_1) Integer
# 0 <= Varx_(181,_2) Integer
# 0 <= Varx_(182,_0) Integer
# 0 <= Varx_(182,_1) Integer
# 0 <= Varx_(182,_2) Integer
# 0 <= Varx_(183,_0) Integer
# 0 <= Varx_(183,_1) Integer
# 0 <= Varx_(183,_2) Integer
# 0 <= Varx_(184,_0) Integer
# 0 <= Varx_(184,_1) Integer
# 0 <= Varx_(184,_2) Integer
# 0 <= Varx_(185,_0) Integer
# 0 <= Varx_(185,_1) Integer
# 0 <= Varx_(185,_2) Integer
# 0 <= Varx_(186,_0) Integer
# 0 <= Varx_(186,_1) Integer
# 0 <= Varx_(186,_2) Integer
# 0 <= Varx_(187,_0) Integer
# 0 <= Varx_(187,_1) Integer
# 0 <= Varx_(187,_2) Integer
# 0 <= Varx_(188,_0) Integer
# 0 <= Varx_(188,_1) Integer
# 0 <= Varx_(188,_2) Integer
# 0 <= Varx_(189,_0) Integer
# 0 <= Varx_(189,_1) Integer
# 0 <= Varx_(189,_2) Integer
# 0 <= Varx_(19,_0) Integer
# 0 <= Varx_(19,_1) Integer
# 0 <= Varx_(19,_2) Integer
# 0 <= Varx_(190,_0) Integer
# 0 <= Varx_(190,_1) Integer
# 0 <= Varx_(190,_2) Integer
# 0 <= Varx_(191,_0) Integer
# 0 <= Varx_(191,_1) Integer
# 0 <= Varx_(191,_2) Integer
# 0 <= Varx_(192,_0) Integer
# 0 <= Varx_(192,_1) Integer
# 0 <= Varx_(192,_2) Integer
# 0 <= Varx_(193,_0) Integer
# 0 <= Varx_(193,_1) Integer
# 0 <= Varx_(193,_2) Integer
# 0 <= Varx_(194,_0) Integer
# 0 <= Varx_(194,_1) Integer
# 0 <= Varx_(194,_2) Integer
# 0 <= Varx_(195,_0) Integer
# 0 <= Varx_(195,_1) Integer
# 0 <= Varx_(195,_2) Integer
# 0 <= Varx_(196,_0) Integer
# 0 <= Varx_(196,_1) Integer
# 0 <= Varx_(196,_2) Integer
# 0 <= Varx_(197,_0) Integer
# 0 <= Varx_(197,_1) Integer
# 0 <= Varx_(197,_2) Integer
# 0 <= Varx_(198,_0) Integer
# 0 <= Varx_(198,_1) Integer
# 0 <= Varx_(198,_2) Integer
# 0 <= Varx_(199,_0) Integer
# 0 <= Varx_(199,_1) Integer
# 0 <= Varx_(199,_2) Integer
# 0 <= Varx_(2,_0) Integer
# 0 <= Varx_(2,_1) Integer
# 0 <= Varx_(2,_2) Integer
# 0 <= Varx_(20,_0) Integer
# 0 <= Varx_(20,_1) Integer
# 0 <= Varx_(20,_2) Integer
# 0 <= Varx_(200,_0) Integer
# 0 <= Varx_(200,_1) Integer
# 0 <= Varx_(200,_2) Integer
# 0 <= Varx_(201,_0) Integer
# 0 <= Varx_(201,_1) Integer
# 0 <= Varx_(201,_2) Integer
# 0 <= Varx_(202,_0) Integer
# 0 <= Varx_(202,_1) Integer
# 0 <= Varx_(202,_2) Integer
# 0 <= Varx_(203,_0) Integer
# 0 <= Varx_(203,_1) Integer
# 0 <= Varx_(203,_2) Integer
# 0 <= Varx_(204,_0) Integer
# 0 <= Varx_(204,_1) Integer
# 0 <= Varx_(204,_2) Integer
# 0 <= Varx_(205,_0) Integer
# 0 <= Varx_(205,_1) Integer
# 0 <= Varx_(205,_2) Integer
# 0 <= Varx_(206,_0) Integer
# 0 <= Varx_(206,_1) Integer
# 0 <= Varx_(206,_2) Integer
# 0 <= Varx_(207,_0) Integer
# 0 <= Varx_(207,_1) Integer
# 0 <= Varx_(207,_2) Integer
# 0 <= Varx_(208,_0) Integer
# 0 <= Varx_(208,_1) Integer
# 0 <= Varx_(208,_2) Integer
# 0 <= Varx_(209,_0) Integer
# 0 <= Varx_(209,_1) Integer
# 0 <= Varx_(209,_2) Integer
# 0 <= Varx_(21,_0) Integer
# 0 <= Varx_(21,_1) Integer
# 0 <= Varx_(21,_2) Integer
# 0 <= Varx_(210,_0) Integer
# 0 <= Varx_(210,_1) Integer
# 0 <= Varx_(210,_2) Integer
# 0 <= Varx_(211,_0) Integer
# 0 <= Varx_(211,_1) Integer
# 0 <= Varx_(211,_2) Integer
# 0 <= Varx_(212,_0) Integer
# 0 <= Varx_(212,_1) Integer
# 0 <= Varx_(212,_2) Integer
# 0 <= Varx_(213,_0) Integer
# 0 <= Varx_(213,_1) Integer
# 0 <= Varx_(213,_2) Integer
# 0 <= Varx_(214,_0) Integer
# 0 <= Varx_(214,_1) Integer
# 0 <= Varx_(214,_2) Integer
# 0 <= Varx_(215,_0) Integer
# 0 <= Varx_(215,_1) Integer
# 0 <= Varx_(215,_2) Integer
# 0 <= Varx_(216,_0) Integer
# 0 <= Varx_(216,_1) Integer
# 0 <= Varx_(216,_2) Integer
# 0 <= Varx_(217,_0) Integer
# 0 <= Varx_(217,_1) Integer
# 0 <= Varx_(217,_2) Integer
# 0 <= Varx_(218,_0) Integer
# 0 <= Varx_(218,_1) Integer
# 0 <= Varx_(218,_2) Integer
# 0 <= Varx_(219,_0) Integer
# 0 <= Varx_(219,_1) Integer
# 0 <= Varx_(219,_2) Integer
# 0 <= Varx_(22,_0) Integer
# 0 <= Varx_(22,_1) Integer
# 0 <= Varx_(22,_2) Integer
# 0 <= Varx_(220,_0) Integer
# 0 <= Varx_(220,_1) Integer
# 0 <= Varx_(220,_2) Integer
# 0 <= Varx_(221,_0) Integer
# 0 <= Varx_(221,_1) Integer
# 0 <= Varx_(221,_2) Integer
# 0 <= Varx_(222,_0) Integer
# 0 <= Varx_(222,_1) Integer
# 0 <= Varx_(222,_2) Integer
# 0 <= Varx_(223,_0) Integer
# 0 <= Varx_(223,_1) Integer
# 0 <= Varx_(223,_2) Integer
# 0 <= Varx_(224,_0) Integer
# 0 <= Varx_(224,_1) Integer
# 0 <= Varx_(224,_2) Integer
# 0 <= Varx_(225,_0) Integer
# 0 <= Varx_(225,_1) Integer
# 0 <= Varx_(225,_2) Integer
# 0 <= Varx_(226,_0) Integer
# 0 <= Varx_(226,_1) Integer
# 0 <= Varx_(226,_2) Integer
# 0 <= Varx_(227,_0) Integer
# 0 <= Varx_(227,_1) Integer
# 0 <= Varx_(227,_2) Integer
# 0 <= Varx_(228,_0) Integer
# 0 <= Varx_(228,_1) Integer
# 0 <= Varx_(228,_2) Integer
# 0 <= Varx_(23,_0) Integer
# 0 <= Varx_(23,_1) Integer
# 0 <= Varx_(23,_2) Integer
# 0 <= Varx_(24,_0) Integer
# 0 <= Varx_(24,_1) Integer
# 0 <= Varx_(24,_2) Integer
# 0 <= Varx_(25,_0) Integer
# 0 <= Varx_(25,_1) Integer
# 0 <= Varx_(25,_2) Integer
# 0 <= Varx_(26,_0) Integer
# 0 <= Varx_(26,_1) Integer
# 0 <= Varx_(26,_2) Integer
# 0 <= Varx_(27,_0) Integer
# 0 <= Varx_(27,_1) Integer
# 0 <= Varx_(27,_2) Integer
# 0 <= Varx_(28,_0) Integer
# 0 <= Varx_(28,_1) Integer
# 0 <= Varx_(28,_2) Integer
# 0 <= Varx_(29,_0) Integer
# 0 <= Varx_(29,_1) Integer
# 0 <= Varx_(29,_2) Integer
# 0 <= Varx_(3,_0) Integer
# 0 <= Varx_(3,_1) Integer
# 0 <= Varx_(3,_2) Integer
# 0 <= Varx_(30,_0) Integer
# 0 <= Varx_(30,_1) Integer
# 0 <= Varx_(30,_2) Integer
# 0 <= Varx_(31,_0) Integer
# 0 <= Varx_(31,_1) Integer
# 0 <= Varx_(31,_2) Integer
# 0 <= Varx_(32,_0) Integer
# 0 <= Varx_(32,_1) Integer
# 0 <= Varx_(32,_2) Integer
# 0 <= Varx_(33,_0) Integer
# 0 <= Varx_(33,_1) Integer
# 0 <= Varx_(33,_2) Integer
# 0 <= Varx_(34,_0) Integer
# 0 <= Varx_(34,_1) Integer
# 0 <= Varx_(34,_2) Integer
# 0 <= Varx_(35,_0) Integer
# 0 <= Varx_(35,_1) Integer
# 0 <= Varx_(35,_2) Integer
# 0 <= Varx_(36,_0) Integer
# 0 <= Varx_(36,_1) Integer
# 0 <= Varx_(36,_2) Integer
# 0 <= Varx_(37,_0) Integer
# 0 <= Varx_(37,_1) Integer
# 0 <= Varx_(37,_2) Integer
# 0 <= Varx_(38,_0) Integer
# 0 <= Varx_(38,_1) Integer
# 0 <= Varx_(38,_2) Integer
# 0 <= Varx_(39,_0) Integer
# 0 <= Varx_(39,_1) Integer
# 0 <= Varx_(39,_2) Integer
# 0 <= Varx_(4,_0) Integer
# 0 <= Varx_(4,_1) Integer
# 0 <= Varx_(4,_2) Integer
# 0 <= Varx_(40,_0) Integer
# 0 <= Varx_(40,_1) Integer
# 0 <= Varx_(40,_2) Integer
# 0 <= Varx_(41,_0) Integer
# 0 <= Varx_(41,_1) Integer
# 0 <= Varx_(41,_2) Integer
# 0 <= Varx_(42,_0) Integer
# 0 <= Varx_(42,_1) Integer
# 0 <= Varx_(42,_2) Integer
# 0 <= Varx_(43,_0) Integer
# 0 <= Varx_(43,_1) Integer
# 0 <= Varx_(43,_2) Integer
# 0 <= Varx_(44,_0) Integer
# 0 <= Varx_(44,_1) Integer
# 0 <= Varx_(44,_2) Integer
# 0 <= Varx_(45,_0) Integer
# 0 <= Varx_(45,_1) Integer
# 0 <= Varx_(45,_2) Integer
# 0 <= Varx_(46,_0) Integer
# 0 <= Varx_(46,_1) Integer
# 0 <= Varx_(46,_2) Integer
# 0 <= Varx_(47,_0) Integer
# 0 <= Varx_(47,_1) Integer
# 0 <= Varx_(47,_2) Integer
# 0 <= Varx_(48,_0) Integer
# 0 <= Varx_(48,_1) Integer
# 0 <= Varx_(48,_2) Integer
# 0 <= Varx_(49,_0) Integer
# 0 <= Varx_(49,_1) Integer
# 0 <= Varx_(49,_2) Integer
# 0 <= Varx_(5,_0) Integer
# 0 <= Varx_(5,_1) Integer
# 0 <= Varx_(5,_2) Integer
# 0 <= Varx_(50,_0) Integer
# 0 <= Varx_(50,_1) Integer
# 0 <= Varx_(50,_2) Integer
# 0 <= Varx_(51,_0) Integer
# 0 <= Varx_(51,_1) Integer
# 0 <= Varx_(51,_2) Integer
# 0 <= Varx_(52,_0) Integer
# 0 <= Varx_(52,_1) Integer
# 0 <= Varx_(52,_2) Integer
# 0 <= Varx_(53,_0) Integer
# 0 <= Varx_(53,_1) Integer
# 0 <= Varx_(53,_2) Integer
# 0 <= Varx_(54,_0) Integer
# 0 <= Varx_(54,_1) Integer
# 0 <= Varx_(54,_2) Integer
# 0 <= Varx_(55,_0) Integer
# 0 <= Varx_(55,_1) Integer
# 0 <= Varx_(55,_2) Integer
# 0 <= Varx_(56,_0) Integer
# 0 <= Varx_(56,_1) Integer
# 0 <= Varx_(56,_2) Integer
# 0 <= Varx_(57,_0) Integer
# 0 <= Varx_(57,_1) Integer
# 0 <= Varx_(57,_2) Integer
# 0 <= Varx_(58,_0) Integer
# 0 <= Varx_(58,_1) Integer
# 0 <= Varx_(58,_2) Integer
# 0 <= Varx_(59,_0) Integer
# 0 <= Varx_(59,_1) Integer
# 0 <= Varx_(59,_2) Integer
# 0 <= Varx_(6,_0) Integer
# 0 <= Varx_(6,_1) Integer
# 0 <= Varx_(6,_2) Integer
# 0 <= Varx_(60,_0) Integer
# 0 <= Varx_(60,_1) Integer
# 0 <= Varx_(60,_2) Integer
# 0 <= Varx_(61,_0) Integer
# 0 <= Varx_(61,_1) Integer
# 0 <= Varx_(61,_2) Integer
# 0 <= Varx_(62,_0) Integer
# 0 <= Varx_(62,_1) Integer
# 0 <= Varx_(62,_2) Integer
# 0 <= Varx_(63,_0) Integer
# 0 <= Varx_(63,_1) Integer
# 0 <= Varx_(63,_2) Integer
# 0 <= Varx_(64,_0) Integer
# 0 <= Varx_(64,_1) Integer
# 0 <= Varx_(64,_2) Integer
# 0 <= Varx_(65,_0) Integer
# 0 <= Varx_(65,_1) Integer
# 0 <= Varx_(65,_2) Integer
# 0 <= Varx_(66,_0) Integer
# 0 <= Varx_(66,_1) Integer
# 0 <= Varx_(66,_2) Integer
# 0 <= Varx_(67,_0) Integer
# 0 <= Varx_(67,_1) Integer
# 0 <= Varx_(67,_2) Integer
# 0 <= Varx_(68,_0) Integer
# 0 <= Varx_(68,_1) Integer
# 0 <= Varx_(68,_2) Integer
# 0 <= Varx_(69,_0) Integer
# 0 <= Varx_(69,_1) Integer
# 0 <= Varx_(69,_2) Integer
# 0 <= Varx_(7,_0) Integer
# 0 <= Varx_(7,_1) Integer
# 0 <= Varx_(7,_2) Integer
# 0 <= Varx_(70,_0) Integer
# 0 <= Varx_(70,_1) Integer
# 0 <= Varx_(70,_2) Integer
# 0 <= Varx_(71,_0) Integer
# 0 <= Varx_(71,_1) Integer
# 0 <= Varx_(71,_2) Integer
# 0 <= Varx_(72,_0) Integer
# 0 <= Varx_(72,_1) Integer
# 0 <= Varx_(72,_2) Integer
# 0 <= Varx_(73,_0) Integer
# 0 <= Varx_(73,_1) Integer
# 0 <= Varx_(73,_2) Integer
# 0 <= Varx_(74,_0) Integer
# 0 <= Varx_(74,_1) Integer
# 0 <= Varx_(74,_2) Integer
# 0 <= Varx_(75,_0) Integer
# 0 <= Varx_(75,_1) Integer
# 0 <= Varx_(75,_2) Integer
# 0 <= Varx_(76,_0) Integer
# 0 <= Varx_(76,_1) Integer
# 0 <= Varx_(76,_2) Integer
# 0 <= Varx_(77,_0) Integer
# 0 <= Varx_(77,_1) Integer
# 0 <= Varx_(77,_2) Integer
# 0 <= Varx_(78,_0) Integer
# 0 <= Varx_(78,_1) Integer
# 0 <= Varx_(78,_2) Integer
# 0 <= Varx_(79,_0) Integer
# 0 <= Varx_(79,_1) Integer
# 0 <= Varx_(79,_2) Integer
# 0 <= Varx_(8,_0) Integer
# 0 <= Varx_(8,_1) Integer
# 0 <= Varx_(8,_2) Integer
# 0 <= Varx_(80,_0) Integer
# 0 <= Varx_(80,_1) Integer
# 0 <= Varx_(80,_2) Integer
# 0 <= Varx_(81,_0) Integer
# 0 <= Varx_(81,_1) Integer
# 0 <= Varx_(81,_2) Integer
# 0 <= Varx_(82,_0) Integer
# 0 <= Varx_(82,_1) Integer
# 0 <= Varx_(82,_2) Integer
# 0 <= Varx_(83,_0) Integer
# 0 <= Varx_(83,_1) Integer
# 0 <= Varx_(83,_2) Integer
# 0 <= Varx_(84,_0) Integer
# 0 <= Varx_(84,_1) Integer
# 0 <= Varx_(84,_2) Integer
# 0 <= Varx_(85,_0) Integer
# 0 <= Varx_(85,_1) Integer
# 0 <= Varx_(85,_2) Integer
# 0 <= Varx_(86,_0) Integer
# 0 <= Varx_(86,_1) Integer
# 0 <= Varx_(86,_2) Integer
# 0 <= Varx_(87,_0) Integer
# 0 <= Varx_(87,_1) Integer
# 0 <= Varx_(87,_2) Integer
# 0 <= Varx_(88,_0) Integer
# 0 <= Varx_(88,_1) Integer
# 0 <= Varx_(88,_2) Integer
# 0 <= Varx_(89,_0) Integer
# 0 <= Varx_(89,_1) Integer
# 0 <= Varx_(89,_2) Integer
# 0 <= Varx_(9,_0) Integer
# 0 <= Varx_(9,_1) Integer
# 0 <= Varx_(9,_2) Integer
# 0 <= Varx_(90,_0) Integer
# 0 <= Varx_(90,_1) Integer
# 0 <= Varx_(90,_2) Integer
# 0 <= Varx_(91,_0) Integer
# 0 <= Varx_(91,_1) Integer
# 0 <= Varx_(91,_2) Integer
# 0 <= Varx_(92,_0) Integer
# 0 <= Varx_(92,_1) Integer
# 0 <= Varx_(92,_2) Integer
# 0 <= Varx_(93,_0) Integer
# 0 <= Varx_(93,_1) Integer
# 0 <= Varx_(93,_2) Integer
# 0 <= Varx_(94,_0) Integer
# 0 <= Varx_(94,_1) Integer
# 0 <= Varx_(94,_2) Integer
# 0 <= Varx_(95,_0) Integer
# 0 <= Varx_(95,_1) Integer
# 0 <= Varx_(95,_2) Integer
# 0 <= Varx_(96,_0) Integer
# 0 <= Varx_(96,_1) Integer
# 0 <= Varx_(96,_2) Integer
# 0 <= Varx_(97,_0) Integer
# 0 <= Varx_(97,_1) Integer
# 0 <= Varx_(97,_2) Integer
# 0 <= Varx_(98,_0) Integer
# 0 <= Varx_(98,_1) Integer
# 0 <= Varx_(98,_2) Integer
# 0 <= Varx_(99,_0) Integer
# 0 <= Varx_(99,_1) Integer
# 0 <= Varx_(99,_2) Integer

# %%
for i in range(len(mDemanda)):
    prob += lpSum(Varx[(i,j)] for j in range(len(mOferta))) == mDemanda[i]

# %%
for i in range(len(mOferta)):
    # Demanda[j][1]*
    prob += lpSum(Varx[(j,i)] for j in range(len(mDemanda))) <= mOferta[i]

# %%
prob.solve()
# Out:
# 1

# %%
for i in prob.variables():
    if i.varValue > 0:
        print(i.name,' carros = ',i.varValue)
# Out:
# Varx_(0,_1)  carros =  2.0
# Varx_(1,_2)  carros =  3.0
# Varx_(10,_0)  carros =  4.0
# Varx_(100,_0)  carros =  1.0
# Varx_(101,_2)  carros =  1.0
# Varx_(102,_0)  carros =  1.0
# Varx_(103,_2)  carros =  1.0
# Varx_(104,_2)  carros =  3.0
# Varx_(105,_0)  carros =  1.0
# Varx_(106,_0)  carros =  1.0
# Varx_(107,_2)  carros =  2.0
# Varx_(108,_2)  carros =  2.0
# Varx_(109,_2)  carros =  2.0
# Varx_(11,_2)  carros =  3.0
# Varx_(110,_0)  carros =  1.0
# Varx_(111,_2)  carros =  2.0
# Varx_(112,_0)  carros =  1.0
# Varx_(113,_2)  carros =  1.0
# Varx_(114,_0)  carros =  1.0
# Varx_(115,_0)  carros =  2.0
# Varx_(116,_0)  carros =  2.0
# Varx_(116,_1)  carros =  3.0
# Varx_(117,_0)  carros =  2.0
# Varx_(118,_0)  carros =  1.0
# Varx_(119,_2)  carros =  1.0
# Varx_(12,_2)  carros =  2.0
# Varx_(120,_2)  carros =  1.0
# Varx_(121,_0)  carros =  1.0
# Varx_(122,_0)  carros =  2.0
# Varx_(123,_2)  carros =  1.0
# Varx_(124,_0)  carros =  1.0
# Varx_(125,_0)  carros =  3.0
# Varx_(126,_2)  carros =  2.0
# Varx_(127,_2)  carros =  10.0
# Varx_(128,_2)  carros =  4.0
# Varx_(129,_2)  carros =  2.0
# Varx_(13,_0)  carros =  3.0
# Varx_(130,_2)  carros =  1.0
# Varx_(131,_0)  carros =  4.0
# Varx_(132,_2)  carros =  1.0
# Varx_(133,_0)  carros =  2.0
# Varx_(134,_0)  carros =  1.0
# Varx_(135,_0)  carros =  3.0
# Varx_(136,_0)  carros =  3.0
# Varx_(137,_0)  carros =  6.0
# Varx_(138,_0)  carros =  3.0
# Varx_(139,_0)  carros =  5.0
# Varx_(14,_2)  carros =  1.0
# Varx_(140,_0)  carros =  5.0
# Varx_(141,_2)  carros =  1.0
# Varx_(142,_0)  carros =  1.0
# Varx_(143,_2)  carros =  2.0
# Varx_(144,_1)  carros =  5.0
# Varx_(145,_2)  carros =  4.0
# Varx_(146,_2)  carros =  2.0
# Varx_(147,_2)  carros =  3.0
# Varx_(148,_0)  carros =  3.0
# Varx_(149,_0)  carros =  3.0
# Varx_(15,_0)  carros =  1.0
# Varx_(150,_0)  carros =  4.0
# Varx_(151,_1)  carros =  8.0
# Varx_(152,_1)  carros =  5.0
# Varx_(153,_0)  carros =  6.0
# Varx_(154,_2)  carros =  3.0
# Varx_(155,_1)  carros =  1.0
# Varx_(156,_2)  carros =  1.0
# Varx_(157,_2)  carros =  2.0
# Varx_(158,_2)  carros =  5.0
# Varx_(159,_0)  carros =  1.0
# Varx_(16,_0)  carros =  1.0
# Varx_(160,_1)  carros =  1.0
# Varx_(161,_0)  carros =  1.0
# Varx_(162,_0)  carros =  1.0
# Varx_(163,_1)  carros =  2.0
# Varx_(164,_0)  carros =  4.0
# Varx_(165,_0)  carros =  3.0
# Varx_(166,_2)  carros =  5.0
# Varx_(167,_1)  carros =  2.0
# Varx_(168,_0)  carros =  5.0
# Varx_(169,_0)  carros =  5.0
# Varx_(17,_2)  carros =  2.0
# Varx_(170,_0)  carros =  1.0
# Varx_(171,_0)  carros =  4.0
# Varx_(172,_2)  carros =  3.0
# Varx_(173,_0)  carros =  1.0
# Varx_(174,_0)  carros =  4.0
# Varx_(175,_2)  carros =  7.0
# Varx_(176,_0)  carros =  2.0
# Varx_(177,_2)  carros =  4.0
# Varx_(178,_2)  carros =  1.0
# Varx_(179,_0)  carros =  4.0
# Varx_(18,_2)  carros =  1.0
# Varx_(180,_2)  carros =  2.0
# Varx_(181,_1)  carros =  4.0
# Varx_(182,_2)  carros =  1.0
# Varx_(183,_0)  carros =  7.0
# Varx_(184,_0)  carros =  7.0
# Varx_(185,_0)  carros =  15.0
# Varx_(186,_0)  carros =  4.0
# Varx_(187,_0)  carros =  2.0
# Varx_(188,_2)  carros =  3.0
# Varx_(189,_2)  carros =  3.0
# Varx_(19,_2)  carros =  1.0
# Varx_(190,_1)  carros =  2.0
# Varx_(191,_0)  carros =  12.0
# Varx_(192,_1)  carros =  5.0
# Varx_(193,_0)  carros =  4.0
# Varx_(194,_0)  carros =  4.0
# Varx_(195,_0)  carros =  8.0
# Varx_(196,_0)  carros =  6.0
# Varx_(197,_0)  carros =  4.0
# Varx_(198,_2)  carros =  2.0
# Varx_(199,_0)  carros =  1.0
# Varx_(2,_2)  carros =  1.0
# Varx_(20,_2)  carros =  2.0
# Varx_(200,_0)  carros =  2.0
# Varx_(201,_0)  carros =  7.0
# Varx_(202,_0)  carros =  1.0
# Varx_(203,_2)  carros =  2.0
# Varx_(204,_0)  carros =  3.0
# Varx_(205,_1)  carros =  1.0
# Varx_(206,_2)  carros =  3.0
# Varx_(207,_0)  carros =  1.0
# Varx_(208,_0)  carros =  5.0
# Varx_(209,_1)  carros =  3.0
# Varx_(21,_2)  carros =  2.0
# Varx_(210,_0)  carros =  1.0
# Varx_(211,_2)  carros =  2.0
# Varx_(212,_1)  carros =  3.0
# Varx_(213,_1)  carros =  1.0
# Varx_(214,_2)  carros =  4.0
# Varx_(215,_0)  carros =  2.0
# Varx_(216,_2)  carros =  2.0
# Varx_(217,_0)  carros =  1.0
# Varx_(218,_2)  carros =  12.0
# Varx_(219,_0)  carros =  2.0
# Varx_(22,_2)  carros =  1.0
# Varx_(220,_0)  carros =  7.0
# Varx_(221,_0)  carros =  2.0
# Varx_(222,_0)  carros =  1.0
# Varx_(223,_2)  carros =  1.0
# Varx_(224,_0)  carros =  4.0
# Varx_(225,_0)  carros =  2.0
# Varx_(226,_0)  carros =  12.0
# Varx_(227,_0)  carros =  1.0
# Varx_(228,_1)  carros =  1.0
# Varx_(23,_2)  carros =  3.0
# Varx_(24,_2)  carros =  7.0
# Varx_(25,_0)  carros =  4.0
# Varx_(26,_0)  carros =  2.0
# Varx_(27,_0)  carros =  6.0
# Varx_(28,_0)  carros =  2.0
# Varx_(29,_1)  carros =  1.0
# Varx_(3,_2)  carros =  1.0
# Varx_(30,_2)  carros =  2.0
# Varx_(31,_0)  carros =  5.0
# Varx_(32,_0)  carros =  4.0
# Varx_(33,_0)  carros =  2.0
# Varx_(34,_0)  carros =  5.0
# Varx_(35,_0)  carros =  1.0
# Varx_(36,_2)  carros =  3.0
# Varx_(37,_2)  carros =  1.0
# Varx_(38,_2)  carros =  3.0
# Varx_(39,_0)  carros =  5.0
# Varx_(4,_2)  carros =  2.0
# Varx_(40,_1)  carros =  2.0
# Varx_(41,_0)  carros =  4.0
# Varx_(42,_2)  carros =  6.0
# Varx_(43,_1)  carros =  4.0
# Varx_(44,_0)  carros =  1.0
# Varx_(45,_0)  carros =  1.0
# Varx_(46,_1)  carros =  6.0
# Varx_(47,_1)  carros =  1.0
# Varx_(48,_2)  carros =  1.0
# Varx_(49,_1)  carros =  5.0
# Varx_(5,_1)  carros =  2.0
# Varx_(50,_0)  carros =  4.0
# Varx_(51,_0)  carros =  2.0
# Varx_(52,_1)  carros =  1.0
# Varx_(53,_0)  carros =  4.0
# Varx_(54,_2)  carros =  1.0
# Varx_(55,_2)  carros =  2.0
# Varx_(56,_0)  carros =  1.0
# Varx_(57,_0)  carros =  1.0
# Varx_(58,_2)  carros =  2.0
# Varx_(59,_0)  carros =  1.0
# Varx_(6,_1)  carros =  2.0
# Varx_(60,_2)  carros =  2.0
# Varx_(61,_1)  carros =  3.0
# Varx_(62,_2)  carros =  5.0
# Varx_(63,_0)  carros =  1.0
# Varx_(64,_0)  carros =  2.0
# Varx_(65,_1)  carros =  5.0
# Varx_(66,_0)  carros =  1.0
# Varx_(67,_0)  carros =  5.0
# Varx_(68,_0)  carros =  1.0
# Varx_(69,_0)  carros =  3.0
# Varx_(7,_2)  carros =  3.0
# Varx_(70,_0)  carros =  3.0
# Varx_(71,_1)  carros =  4.0
# Varx_(72,_0)  carros =  1.0
# Varx_(73,_1)  carros =  1.0
# Varx_(74,_0)  carros =  9.0
# Varx_(75,_0)  carros =  12.0
# Varx_(76,_0)  carros =  2.0
# Varx_(77,_2)  carros =  2.0
# Varx_(78,_0)  carros =  1.0
# Varx_(79,_0)  carros =  1.0
# Varx_(8,_0)  carros =  4.0
# Varx_(80,_2)  carros =  5.0
# Varx_(81,_0)  carros =  1.0
# Varx_(82,_2)  carros =  5.0
# Varx_(83,_2)  carros =  1.0
# Varx_(84,_0)  carros =  2.0
# Varx_(85,_0)  carros =  3.0
# Varx_(86,_0)  carros =  2.0
# Varx_(87,_0)  carros =  4.0
# Varx_(88,_0)  carros =  5.0
# Varx_(89,_0)  carros =  3.0
# Varx_(9,_1)  carros =  6.0
# Varx_(90,_0)  carros =  2.0
# Varx_(91,_0)  carros =  2.0
# Varx_(92,_2)  carros =  1.0
# Varx_(93,_0)  carros =  1.0
# Varx_(94,_1)  carros =  4.0
# Varx_(95,_1)  carros =  2.0
# Varx_(96,_2)  carros =  3.0
# Varx_(97,_2)  carros =  5.0
# Varx_(98,_2)  carros =  1.0
# Varx_(99,_2)  carros =  3.0
